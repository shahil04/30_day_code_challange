# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
# https://www.business-standard.com/
#     https://timesofindia.indiatimes.com/
#         https://www.thehindu.com/
#             https://indianexpress.com/
#                 https://www.indiatoday.in/#hindi news
#                     https://www.ndtv.com/#hindi news

# %%
url1="https://timesofindia.indiatimes.com"
#div class="top-story"
page_response=requests.get(url1)

# %%
html_page=bs(page_response.content,"lxml")

# %%
top_story=html_page.find("div",{"class":"top-story"})

# %%
news=top_story.findAll('a')

# %%
len(news)
news_links=[]
news_title=[]
news_description=[]

# %%
news[0]["title"]
# Out:
# 'Live: No ration in Goa to those not wearing masks'

# %%
for a in news:
    news_links.append(url1+a["href"])

# %%
len(news_links)
# Out:
# 10

# %%
news_links[0]
# Out:
# 'https://timesofindia.indiatimes.com/india/coronavirus-india-updates-live-special-train-ferries-stranded-migrants-from-telangana-to-jharkhand/liveblog/75461685.cms'

# %%
page=requests.get(news_links[1])
soup=bs(page.content,"lxml")
tit=soup.find("h1",{"class":"as_heading"})
describtions=soup.find("div",{"class":"_3WlLe clearfix"})

# %%
soup.find
# Out:
# <bound method Tag.find of <!DOCTYPE html>
# ...

# %%
th_url="https://www.thehindu.com/"
response=requests.get(th_url)
th_soup=bs(response.content,"lxml")

# %%
e=th_soup.find("div",{"class":"promoted-story trending-carousel-container tThHinduTdayCr-cont"})

# %%
e
# Out:
# <div class="promoted-story trending-carousel-container tThHinduTdayCr-cont" data-category="trending-on-hindu" data-label="homepage">
# <div class="promoted-story-heading trending-carousel-heading-container">
# <h4><span calss="promoted-news-heading trending-carousel-heading left tThHinduTdayCr-heading">
# Trending on The Hindu
# </span></h4> </div>
# <div class="tc1-slider tc1-slider1 tThHinduTdayCr-slider">
# <div class="tc1-slide">
# <h5>
# <a class="tc-text-block" href="https://www.thehindu.com/news/international/oman-orders-firing-of-expats-from-state-sector-companies/article31471051.ece" title="Updated: April 30, 2020 23:19 IST
# Published: April 30, 2020 14:46 IST">
# <span class="section-heading">
# <i class="fa fa-eye"></i> 80K
# </span>
# Oman orders firing of expats from state sector companies
# </a>
# </h5>
# </div>
# <div class="tc1-slide">
# <h5>
# ...

# %%
for i, j in enumerate(e("a")):
    print(str(i)+"  " +j["href"])
# Out:
# 0  https://www.thehindu.com/news/international/oman-orders-firing-of-expats-from-state-sector-companies/article31471051.ece
# 1  https://www.thehindu.com/entertainment/movies/rishi-kapoor-veteran-hindi-actor-passes-away/article31469211.ece
# 2  https://www.thehindu.com/entertainment/movies/angelina-jolie-natalie-portman-remember-co-star-irrfan-khan/article31470610.ece
# 3  https://www.thehindu.com/news/national/india-coronavirus-lockdown-april-30-2020-live-updates/article31469180.ece
# 4  https://www.thehindu.com/news/national/coronavirus-lockdown-home-ministry-clears-inter-state-movement-of-stranded-people/article31465698.ece
# 5  https://www.thehindu.com/entertainment/movies/ajith-was-in-the-hospital-bed-when-i-narrated-the-script-rajiv-menon-on-20-years-of-kandukondain-kandukondain/article31470361.ece
# 6  https://www.thehindu.com/news/national/covid-19-health-ministry-lists-red-orange-and-green-zone-districts-for-week-after-may-3/article31478592.ece
# ...

# %%
th_soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# The Hindu: Breaking News, India News, Sports News and Live Updates
# </title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Breaking News, India News, Sports News and Live Updates" name="title"/>
# <meta content="homepage" name="atdlayout"/> <meta content="Today's News Headlines, Breaking News &amp; Latest News from India and World, News from Politics, Sports, Business, Arts and Entertainment" name="description"/>
# <meta content="Breaking News, India News, Sports News and Live Updates" name="twitter:title"/>
# <meta content="Today's News Headlines, Breaking News &amp; Latest News from India and World, News from Politics, Sports, Business, Arts and Entertainment" name="twitter:description"/>
# ...

# %%
just_in=th_soup.findAll("div",{"class":"justIn-story"})

# %%
just_in[0].findAll("a")
# Out:
# [<a href="https://www.thehindu.com/news/cities/chennai/chennai-police-commissioner-inspects-koyambedu-market/article31480254.ece" title="Updated: May 1, 2020 13:59 IST
#  Published: May 1, 2020 13:59 IST">
#  <span class="justIn-number"></span>
#  <span class="red-color">
#  <i class="fa fa-clock-o"></i>
#  <span>19mins</span>
#  </span>
#  Chennai Police Commissioner inspects Koyambedu market </a>,
#  <a href="https://www.thehindu.com/news/national/tamil-nadu/10-myanmar-nationals-shifted-to-puzhal-prison/article31480075.ece" title="Updated: May 1, 2020 13:46 IST
#  Published: May 1, 2020 13:46 IST">
#  <span class="justIn-number"></span>
#  <span class="red-color">
#  <i class="fa fa-clock-o"></i>
#  <span>33mins</span>
#  </span>
#  10 Myanmar nationals shifted to Puzhal prison
#  </a>,
#  <a href="https://www.thehindu.com/news/cities/chennai/22-year-old-house-surgeon-found-dead-in-kilpauk-medical-college-hostel/article31480030.ece" title="Updated: May 1, 2020 13:42 IST
# ...

# %%
link=[]
i=0
for a in just_in:
    link.append(a.findAll("a"))

# %%
len(link)
# Out:
# 5

# %%
i=0
just_link=[]
while i<len(link):
    for j in link[i]:
        just_link.append(j["href"])
    i+=1

# %%
len(set(just_link))
# Out:
# 15

# %%
just_link[0]
# Out:
# 'https://www.thehindu.com/news/cities/chennai/chennai-police-commissioner-inspects-koyambedu-market/article31480254.ece'

# %%
just_link_req=requests.get(just_link[2])
jls=bs(just_link_req.content,"lxml")

# %%
jls_title=jls.find("h1",{"class":"title"}).text

# %%
print(jls_title.strip())
# Out:
# 22-year-old house surgeon found dead in Kilpauk Medical College hostel

# %%
img=jls.findAll("div",{"class":"img-container picture"})

# %%
image_grids = jls.select('img-container picture')

# %%
img1=jls.find("img",{"class":"lead-img adaptive placeholder"})

# %%
img1
# Out:
# <img alt="A health worker seen spraying disinfectant at Government Kilpauk Medical College Hospital, 10 days ago. Photograph used for representational purposes only" class="lead-img adaptive placeholder" data-device-variant="FREE~FREE~FREE" data-src-template="https://th.thgim.com/news/cities/chennai/9lddrj/article31480029.ece/BINARY/thumbnail/01MAYTH--KMC" data-variant="FREE" src="https://www.thehindu.com/static/img/1x1_spacer.png" title="A health worker seen spraying disinfectant at Government Kilpauk Medical College Hospital, 10 days ago. Photograph used for representational purposes only"/>

# %%
jls.find("source")
# Out:
# <source media="(min-width: 1281px)" sizes="960px" srcset="https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_960/01MAYTH--KMC">
# <source media="(min-width: 421px) and (max-width: 1280px)" sizes="660px" srcset="https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_660/01MAYTH--KMC">
# <source media="(min-width: 321px) and (max-width: 420px)" sizes="435px" srcset="https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_435/01MAYTH--KMC">
# <source media="(max-width: 320px)" sizes="320px" srcset="https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_320/01MAYTH--KMC">
# <!--[if IE 9]></video><![endif]-->
# ...

# %%
for el in jls.findAll('source', attrs = {'srcset' : True}):
    print (el['srcset'])
# Out:
# https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_960/01MAYTH--KMC
# https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_660/01MAYTH--KMC
# https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_435/01MAYTH--KMC
# https://www.thehindu.com/news/cities/chennai/9lddrj/article31480029.ece/ALTERNATES/FREE_320/01MAYTH--KMC

# %%
de=jls.find("div",{"class":"article"})

# %%
pe=de.findAll("p")

# %%
np=pe[:-15]

# %%
for t in np:
    print(t.text)
# Out:
# A health worker seen spraying disinfectant at Government Kilpauk Medical College Hospital, 10 days ago. Photograph used for representational purposes only
#   | Photo Credit:
# B. VELANKANNI RAJ
#
#
# A 22-year- old woman house surgeon was found lying dead in her hostel room in Government Kilpauk Medical College Hospital on Friday morning.
# Since the lockdown came into effect, the woman had come from her house in Perambur, and had been staying in the hostel from April 14 onwards. On Friday morning, she did not come out from her room, and did not respond to anyone. On receiving information, police personnel from Kilpauk went there. The woman was rushed to the hospital where she was declared brought dead.
# “The cause of death is not immediately known and samples have been collected for testing,” said a senior police officer. A case was registered by the Kilpauk police for unnatural death. Further investigations are on.
# ...

# %% [markdown]
# # tranding news of the hindu

# %%
th_soup.findAll("div",{"class":"tc1-slide slick-slide slick-cloned"})
# Out:
# []
