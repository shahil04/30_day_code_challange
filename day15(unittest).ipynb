# %% [markdown]
# ## Unit testing
#
# Test smallest parts of an application in isolation (e.g. units)<br>
# Good candidates for unit testing: individual classes, modules, or functions<br>
# Bad candidates for unit testing: an entire application, dependencies across several classes or modules<br>

# %% [markdown]
# ### unittest
#
# Python comes with a built-in module called unittest<br>
# You can write unit tests encapsulated as classes that inherit from unittest.TestCase<br>
# This inheritance gives you access to many assertion helpers that let you test the behavior of your functions<br>
# You can run tests by calling unittest.main()<br>

# %%
# Commenting Tests
class SomeTests(unittest.TestCase):
    def first_test(self):
        """testing a thing"""
        self.assertEqual(thing(), "something")

    def second_test(self):
        """testing another thing"""
        self.assertEqual(another_thing(), "something else")

        
# To see comments, run

# python NAME_OF_TEST_FILE.py -v

# %% [raw]
# types of esserstions
#
# self.assertEqual(x, y)
# self.assertNotEqual(x, y)
# self.assertTrue(x)
# self.assertFalse(x)
# self.assertIsNone(x)
# self.assertIsNotNone(x)
# self.assertIn(x, y)
# self.assertNotIn(x, y)
# ...and more!

# %%
# Testing For Error use assertRaises

class SomeTests(unittest.TestCase):
    def testing_for_error(self):
        """testing for an error"""
        with self.assertRaises(IndexError):
            l = [1,2,3]
            l[100]

# %%
# unitesting_file.py

def eat(food,ishealthy):
    if ishealthy:
        return "veg food is healthy"
    return "lol"

def check_num(num):
    if num<2:
        return "this is 1"
    return "this is 3"

# %%
# this is a test file
# unittest_test_class.py

import unittest
from unitesting_file import eat,check_num


class Testactivity(unittest.TestCase):
    
    def test_eats(self):
        """this is veg"""
        self.assertEqual(
            eat("veg",ishealthy=True),
            "veg food is healthy"
        )
    
    def test_eat(self):
        """this is non veg"""
        self.assertEqual(
            eat("non-veg",ishealthy=False),
            "lol"
        )
      
        
    def test_check_num(self):
        """this is 3"""
        self.assertEqual(
        check_num(3),
        "this is 3"
        )
        
    def test_num(self):
        """this is 1"""
        self.assertEqual(
           check_num(1),
            "this is 1"
        )
       
if __name__=="__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /home/rahish/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/home/rahish/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.025s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /home/rahish/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## after run in terminal result

# %% [raw]
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
#
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unitesting_file.py
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# E
# ======================================================================
# ERROR: test_check_sum (__main__.Tests)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 20, in test_check_sum
#     check_sum(3),
# NameError: name 'check_sum' is not defined
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# E
# ======================================================================
# ERROR: test_check_num (__main__.Tests)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 20, in test_check_num
#     check_sum(3),
# NameError: name 'check_sum' is not defined
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (errors=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_check_num (__main__.Tests)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 21, in test_check_num
#     "this is 3 and it is wow"
# AssertionError: None != 'this is 3 and it is wow'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_check_num (__main__.Tests)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 22, in test_check_num
#     "this is 3 and it is wow"
# AssertionError: None != 'this is 3 and it is wow'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_check_num (__main__.Tests)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 22, in test_check_num
#     "this is 3 and it is wow"
# AssertionError: None != 'this is 3 and it is wow'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 2, in <module>
#     from unitest_file import eat,check_num
# ModuleNotFoundError: No module named 'unitest_file'
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg foog is healthy"
# AssertionError: None != 'veg foog is healthy'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: None != 'veg food is healthy'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: None != 'veg food is healthy'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: None != 'veg food is healthy'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
#
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python demo_test.py
# F
# ======================================================================
# FAIL: test_eat (__main__.DemoTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "demo_test.py", line 9, in test_eat
#     "challi"
# AssertionError: None != 'challi'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python demo_test.py
# FF
# ======================================================================
# FAIL: test_eat (__main__.DemoTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "demo_test.py", line 9, in test_eat
#     "challi"
# AssertionError: None != 'challi'
#
# ======================================================================
# FAIL: test_uneat (__main__.DemoTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "demo_test.py", line 14, in test_uneat
#     "tea"
# AssertionError: None != 'tea'
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.001s
#
# FAILED (failures=2)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 10, in test_eat
#     "veg food is healthy"
# AssertionError: 'lol' != 'veg food is healthy'
# - lol
# + veg food is healthy
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 16, in test_eat
#     "non veg is not healthy."
# AssertionError: 'non veg is not healthy' != 'non veg is not healthy.'
# - non veg is not healthy
# + non veg is not healthy.
# ?                       +
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# F
# ======================================================================
# FAIL: test_eat (__main__.Testactivity)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "unittest_testing_class.py", line 16, in test_eat
#     "lol."
# AssertionError: 'lol' != 'lol.'
# - lol
# + lol.
# ?    +
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (failures=1)
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py -v
# test_eat (__main__.Testactivity) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py -v
# test_check_num (__main__.Testactivity) ... ok
# test_eat (__main__.Testactivity) ... ok
# test_num (__main__.Testactivity) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py -v
# test_check_num (__main__.Testactivity)
# this is 3 ... ok
# test_eat (__main__.Testactivity)
# this is non veg ... ok
# test_num (__main__.Testactivity)
# this is 1 ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py -v
# test_check_num (__main__.Testactivity)
# this is 3 ... ok
# test_eat (__main__.Testactivity)
# this is non veg ... ok
# test_num (__main__.Testactivity)
# this is 1 ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.000s
#
# OK
# rahish@rahish-Lenovo-ideapad-320-15ISK:~/Desktop/30_days_code_challange$ python3 unittest_testing_class.py -v
# test_check_num (__main__.Testactivity)
# this is 3 ... ok
# test_eat (__main__.Testactivity)
# this is non veg ... ok
# test_eats (__main__.Testactivity)
# this is veg ... ok
# test_num (__main__.Testactivity)
# this is 1 ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.001s
#
# OK

# %% [markdown]
# ## Before and After Hooks
#
# ## setUp and tearDown
#
# For larger applications, you may want similar application state before running tests<br>
# setUp runs before each test method<br>
# tearDown runs after each test method<br>
# Common use cases: adding/removing data from a test database, creating instances of a class<br>

# %%
## Example

class SomeTests(unittest.TestCase):

    def setUp(self):
        # do setup here
        pass

    def test_first(self):
        # setUp runs before
        # tearDown runs after
        pass

    def test_second(self):
        # setUp runs before
        # tearDown runs after
        pass

    def tearDown(self):
        # do teardown here
        pass

# %% [markdown]
# ## Recap
#
# Tests help streamline development and reduce bugs<br>
# You can start with tests if doing TDD / Red, Green, Refactor<br>
# You can perform simple checks with assert<br>
# You can test with doctests, but typically shouldn't<br>
# unittest is a feature-rich, OOP style testing library in Python<br>
# To reduce code duplication in tests, use before/after hooks!<br>
